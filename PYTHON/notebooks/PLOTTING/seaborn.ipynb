# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from utils import globalsettings as gs
import pandas as pd

# %%
df = pd.read_csv(gs.the_files.ATTRITION)

# %% [markdown]
# # Basics
#
# Seaborn es una biblioteca de visualización de datos en Python basada en Matplotlib. Proporciona una interfaz de alto nivel para dibujar gráficos estadísticos atractivos e informativos.

# %%
# Configura el estilo del gráfico (opcional)
sns.set(style="whitegrid")

# %% [markdown]
# Gráficos de Distribución

# %%
sns.histplot(data=df, x="Age", kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.boxplot(x="Department", y="Age", data=df)
# Out:
# <Axes: xlabel='Department', ylabel='Age'>

# %% [markdown]
# Gráficos de Relación

# %%
sns.scatterplot(x="Age", y="YearsAtCompany", data=df)
# Out:
# <Axes: xlabel='Age', ylabel='YearsAtCompany'>

# %%
sns.pairplot(df[df.columns[:10]])
# Out:
# c:\Users\mcondedesimon\OneDrive - Deloitte (O365D)\Documents\PLAYGROUND\explo_py\.venv\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# Gráficos categóricos

# %%
sns.barplot(x='Department', y='Age', data=df)
# Out:
# <Axes: xlabel='Department', ylabel='Age'>

# %% [markdown]
# Gráficos de Matriz

# %%
# Seleccionando solo las columnas numéricas
numerical_columns = df.select_dtypes(include=['number'])

# Calculando la matriz de correlación para las columnas numéricas
correlation_matrix = numerical_columns.corr()

sns.heatmap(data=correlation_matrix, cmap="YlGnBu", vmin = -1, vmax = 1)
# Out:
# <Axes: >

# %% [markdown]
# FacetGrid

# %%
g = sns.FacetGrid(df, col="Department", row="Education")
g.map(sns.histplot, "JobSatisfaction")
# Out:
# c:\Users\mcondedesimon\OneDrive - Deloitte (O365D)\Documents\PLAYGROUND\explo_py\.venv\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Creando un objeto FacetGrid, definiendo las columnas y filas según el departamento y el nivel de educación
g = sns.FacetGrid(df, col="Department", row="Education", margin_titles=True)

# Aplicando un histograma de la satisfacción laboral en cada faceta
g.map(sns.histplot, "JobSatisfaction", bins=10, color="skyblue", edgecolor="black")

# Añadiendo títulos y etiquetas
g.set_axis_labels("Satisfacción Laboral", "Frecuencia")
g.set_titles(col_template="{col_name} Departamento", row_template="Educación {row_name}")
g.set(xlim=(0, df['JobSatisfaction'].max()), ylim=(0, None))

# Ajustando el diseño
g.tight_layout()

# Mostrando el gráfico
plt.show()
# Out:
# c:\Users\mcondedesimon\OneDrive - Deloitte (O365D)\Documents\PLAYGROUND\explo_py\.venv\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# Relación con Matplotlib
#
# Solapamiento: Seaborn está construido sobre Matplotlib, por lo que puedes utilizar funciones y métodos de Matplotlib junto con Seaborn para personalizar aún más los gráficos.
#
# Complementariedad: Seaborn simplifica la creación de muchos tipos de gráficos que requieren múltiples líneas de código en Matplotlib. Ofrece una interfaz más sencilla y estilizada.
#
# Diferencias: Aunque Seaborn facilita la creación de gráficos estadísticos complejos, Matplotlib ofrece más control sobre los detalles de bajo nivel de los gráficos.
#
# Estilos y Paletas: Seaborn viene con estilos y paletas de colores predefinidos que hacen que los gráficos sean visualmente atractivos de manera predeterminada.
#
# En resumen, Seaborn amplía las capacidades de Matplotlib, ofreciendo una interfaz más amigable y estilizada para crear gráficos estadísticos. Puedes utilizar ambas bibliotecas juntas para aprovechar la facilidad de uso de Seaborn y el control detallado de Matplotlib.
#
# Si tienes alguna pregunta específica o si hay algo en particular que te gustaría aprender más, ¡estaré encantado de ayudarte!

# %% [markdown]
# # Estilos y colores
#
# Seaborn facilita la creación de gráficos atractivos y coherentes a través de la utilización de estilos y paletas de colores. Veamos cómo puedes utilizar estos elementos en Seaborn:
#
# 1. Estilos Predefinidos
#
# Seaborn ofrece una serie de estilos predefinidos que puedes aplicar a tus gráficos. Estos estilos controlan la apariencia de los elementos del gráfico, como el fondo, las líneas de cuadrícula y los colores.
#
# Puedes aplicar un estilo utilizando la función sns.set_style. Aquí hay algunos estilos comunes:
#
#     + "white": Fondo blanco sin líneas de cuadrícula.
#     + "dark": Fondo oscuro sin líneas de cuadrícula.
#     + "whitegrid": Fondo blanco con líneas de cuadrícula.
#     + "darkgrid": Fondo oscuro con líneas de cuadrícula.
#     + "ticks": Fondo blanco con marcas en los ejes.

# %%
sns.set_style("whitegrid")
sns.boxplot(x="Department", y="Age", data=df)
plt.show()

# %%
sns.set_style("darkgrid")
sns.boxplot(x="Department", y="Age", data=df)
plt.show()

# %% [markdown]
# Paletas de Colores
#
# Seaborn también ofrece una variedad de paletas de colores que puedes utilizar para colorear los elementos de tu gráfico. Las paletas de colores son conjuntos coherentes de colores que funcionan bien juntos.
#
# Puedes aplicar una paleta de colores utilizando la función sns.set_palette. Algunas paletas comunes incluyen:
#
#     + "deep"
#     + "muted"
#     + "bright"
#     + "pastel"
#     + "dark"
#     + "colorblind"

# %%
sns.set_palette("pastel")
sns.barplot(x="Department", y="Age", data=df)
plt.show()

# %%
sns.set_palette("deep")
sns.barplot(x="Department", y="Age", data=df)
plt.show()

# %% [markdown]
# Las paletas de colores en Seaborn están diseñadas para diferentes propósitos y contextos, y elegir la paleta adecuada puede ayudar a transmitir mejor la información en tu gráfico. A continuación, te describo algunas paletas comunes y sus usos típicos:
#
# 1. "deep"
#     + Apropiada para: Gráficos generales con colores distintivos y saturados.
#     + Uso: Cuando necesitas diferenciar claramente entre varias categorías.
#
#
# 2. "muted"
#     + Apropiada para: Gráficos que requieren colores menos llamativos.
#     + Uso: Similar a "deep", pero con tonos más suaves, lo que puede ser útil cuando se desea un aspecto más sutil.
#
#
# 3. "bright"
#     + Apropiada para: Gráficos que necesitan colores vivos y brillantes.
#     + Uso: Cuando se desea destacar categorías o elementos específicos en los datos.
#
# 4. "pastel"
#     + Apropiada para: Gráficos que requieren colores suaves y agradables.
#     + Uso: Ideal para presentaciones donde los colores brillantes y saturados pueden ser demasiado abrumadores.
#
# 5. "dark"
#     + Apropiada para: Gráficos que requieren colores oscuros y saturados.
#     + Uso: Puede ser útil para destacar elementos en un fondo claro.
#
# 6. "colorblind"
#     + Apropiada para: Gráficos destinados a una audiencia que pueda incluir personas con daltonismo.
#     + Uso: Asegura que los colores sean distinguibles para aquellos con deficiencias de visión de color.
#
# 7. Paletas Secuenciales
#     + Apropiada para: Representar datos ordenados, donde hay una progresión clara de un valor bajo a uno alto.
#     + Uso: Mapas de calor, gráficos de contorno y cualquier visualización que represente una secuencia o gradiente.
#
# 8. Paletas Divergentes
#     + Apropiada para: Datos donde hay un punto medio interesante y valores divergentes a ambos lados.
#     + Uso: Comparación de desviaciones respecto a un punto central, como en gráficos de diferencias o anomalías.
#
# 9. Paletas Cúbicas Helix (cubehelix)
#     + Apropiada para: Representar datos en escala de grises con un cambio en brillo.
#     + Uso: Gráficos que serán impresos en blanco y negro o para aquellos con deficiencias de visión de color.

# %% [markdown]
# Combinación de Estilos y Paletas
#
# Puedes combinar estilos y paletas de colores para crear una apariencia coherente en todos tus gráficos. La función sns.set te permite configurar ambos a la vez:

# %%
sns.set(style="darkgrid", palette="muted")
sns.barplot(x="Department", y="Age", data=df)
plt.show()

# %% [markdown]
# Contexto de Dibujo
#
# Seaborn también te permite ajustar el contexto de dibujo, lo cual afecta el tamaño y la complejidad de los elementos del gráfico (por ejemplo, el tamaño de las etiquetas). Puedes utilizar sns.set_context para esto, con opciones como "paper", "notebook", "talk", y "poster".
#
# Resumen
#
# Los estilos y paletas de colores en Seaborn te permiten crear gráficos atractivos y coherentes con muy poco esfuerzo. Al aplicar estos elementos, puedes garantizar que tus gráficos sean fáciles de leer y visualmente agradables, sin tener que ajustar manualmente muchos detalles.

# %% [markdown]
# # Caso de Uso - EDA
#
# ## Gráficos Simples
#
# ### Histogramas y density plots

# %%
# Configurando el estilo del gráfico
sns.set(style="whitegrid")

# Creando un histograma de la columna "Age"
sns.histplot(data=df, x="Age", bins=15, kde=True, color="skyblue", edgecolor="black")

# Añadiendo títulos y etiquetas
plt.title("Distribución de las Edades de los Empleados")
plt.xlabel("Edad")
plt.ylabel("Frecuencia")

# Mostrando el gráfico
plt.show()

# %%
# Configurando el estilo del gráfico
sns.set(style="whitegrid")

# Creando un gráfico de densidad (KDE) de "JobSatisfaction" diferenciando por "Department"
sns.kdeplot(data=df, x="JobSatisfaction", hue="Department", common_norm=False, fill=True)

# Añadiendo títulos y etiquetas
plt.title("Distribución de la Satisfacción Laboral por Departamento")
plt.xlabel("Satisfacción Laboral")
plt.ylabel("Densidad")

# Mostrando el gráfico
plt.show()

# %%
# Creando nuevamente el gráfico de densidad (KDE) de "JobSatisfaction" diferenciando por "Department"
sns.kdeplot(data=df, x="JobSatisfaction", hue="Department", common_norm=False, fill=True)

# Añadiendo títulos y etiquetas
plt.title("Distribución de la Satisfacción Laboral por Departamento")
plt.xlabel("Satisfacción Laboral")
plt.ylabel("Densidad")

# Moviendo la leyenda a la esquina superior derecha
plt.legend(loc='upper right')

# Mostrando el gráfico
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Creando nuevamente el gráfico de densidad (KDE) de "JobSatisfaction" diferenciando por "Department"
kde_plot = sns.kdeplot(data=df, x="JobSatisfaction", hue="Department", common_norm=False, fill=True)

# Añadiendo títulos y etiquetas
plt.title("Distribución de la Satisfacción Laboral por Departamento")
plt.xlabel("Satisfacción Laboral")
plt.ylabel("Densidad")

# Moviendo la leyenda a la esquina superior derecha
sns.move_legend(kde_plot, loc='upper left')

# Mostrando el gráfico
plt.show()

# %% [markdown]
# ### Barcharts

# %%
# Configurando el estilo del gráfico
sns.set(style="whitegrid")

# Creando un gráfico de barras para mostrar la media de "JobSatisfaction" en cada "Department"
sns.barplot(x="Department", y="JobSatisfaction", data=df, errorbar=None, palette="pastel")

# Añadiendo títulos y etiquetas
plt.title("Media de la Satisfacción Laboral por Departamento")
plt.xlabel("Departamento")
plt.ylabel("Media de Satisfacción Laboral")

# Mostrando el gráfico
plt.show()

# %%
# Configurando el estilo del gráfico
sns.set(style="whitegrid")

# Creando un gráfico de barras para mostrar el número de empleados que han dejado y los que permanecen
sns.countplot(x="Attrition", data=df, palette="coolwarm")

# Añadiendo títulos y etiquetas
plt.title("Número de Empleados que han Dejado vs Permanecen")
plt.xlabel("Atrición")
plt.ylabel("Número de Empleados")

# Mostrando el gráfico
plt.show()

# %% [markdown]
# ## Gráficos de Comparación
#
# ### Boxplots

# %%
# Configurando el estilo del gráfico
sns.set(style="whitegrid")

# Creando un boxplot para estudiar la distribución de "Age" en cada "Department"
sns.boxplot(x="Department", y="Age", data=df, palette="Set2")

# Añadiendo títulos y etiquetas
plt.title("Distribución de las Edades por Departamento")
plt.xlabel("Departamento")
plt.ylabel("Edad")

# Mostrando el gráfico
plt.show()

# %%
# Creando nuevamente el boxplot con un valor de whis más bajo para resaltar más los outliers
sns.boxplot(x="Department", y="Age", data=df, palette="Set2", whis=1.1)

# Añadiendo títulos y etiquetas
plt.title("Distribución de las Edades por Departamento")
plt.xlabel("Departamento")
plt.ylabel("Edad")

# Mostrando el gráfico
plt.show()

# %% [markdown]
# ### Violin plots

# %%
# Configurando el estilo del gráfico
sns.set(style="whitegrid")

# Creando un gráfico de violín para estudiar la distribución de "Age" en cada "Department"
sns.violinplot(x="Department", y="Age", data=df, palette="Set3", inner="quartile")

# Añadiendo títulos y etiquetas
plt.title("Distribución de las Edades por Departamento")
plt.xlabel("Departamento")
plt.ylabel("Edad")

# Mostrando el gráfico
plt.show()

# %% [markdown]
# ### Scatterplots

# %%
# Configurando el estilo del gráfico
sns.set(style="whitegrid")

# Creando un gráfico de dispersión para "Age" vs "YearsAtCompany"
sns.scatterplot(x="Age", y="YearsAtCompany", data=df, color="blue", edgecolor="black")

# Añadiendo títulos y etiquetas
plt.title("Edad vs. Años en la Compañía")
plt.xlabel("Edad")
plt.ylabel("Años en la Compañía")

# Mostrando el gráfico
plt.show()

# %%
# Creando una figura con 2 subplots en formato (1, 2)
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# Primer subplot: Violinplot para Edad por Departamento
sns.violinplot(x="Department", y="Age", data=df, palette="Set3", inner="quartile", ax=axes[0])
axes[0].set_title("Distribución de las Edades por Departamento")
axes[0].set_xlabel("Departamento")
axes[0].set_ylabel("Edad")

# Segundo subplot: Scatterplot para Edad vs. Años en la Compañía
sns.scatterplot(x="Age", y="YearsAtCompany", data=df, color="blue", edgecolor="black", ax=axes[1])
axes[1].set_title("Edad vs. Años en la Compañía")
axes[1].set_xlabel("Edad")
axes[1].set_ylabel("Años en la Compañía")

# Título general para toda la figura (sin cambios)
fig.suptitle('Ejemplo de subplots', fontsize=16, y=1.02)

# Ajustando el diseño para evitar superposición
plt.tight_layout()

# Mostrando la figura
plt.show()

# %% [markdown]
# ## Gráficos multivariados
#
# ### Barras apiladas

# %%
# Agrupando los datos por "Department" y "Attrition" y calculando la cantidad de empleados en cada categoría
attrition_by_department = df.groupby(['Department', 'Attrition']).size().unstack().fillna(0)

# Normalizando los datos para representar las proporciones
attrition_by_department_normalized = attrition_by_department.div(attrition_by_department.sum(axis=1), axis=0)

attrition_by_department_normalized
# Out:
# Attrition                     No       Yes
# Department
# Human Resources         0.809524  0.190476
# Research & Development  0.861602  0.138398
# Sales                   0.793722  0.206278

# %%
# Creando una figura
plt.figure(figsize=(10, 6))

# Obteniendo las columnas correspondientes a "Permanecen" y "Dejaron"
permanecen = attrition_by_department_normalized.iloc[:, 0]
dejaron = attrition_by_department_normalized.iloc[:, 1]

# Dibujando las barras para "Permanecen"
sns.barplot(x=attrition_by_department_normalized.index, y=permanecen, color='blue', label="Permanecen")

# Dibujando las barras para "Dejaron" encima de "Permanecen"
sns.barplot(x=attrition_by_department_normalized.index, y=dejaron, color='red', bottom=permanecen, label="Dejaron")

# Añadiendo las etiquetas de texto con los porcentajes
for index, value in enumerate(permanecen):
    plt.text(index, value/2, f"{value:.1%}", ha='center', color='white', fontsize=10)
    plt.text(index, permanecen[index] + dejaron[index]/2, f"{dejaron[index]:.1%}", ha='center', color='white', fontsize=10)

# Añadiendo títulos y etiquetas
plt.title("Tasa de Abandono por Departamento")
plt.xlabel("Departamento")
plt.ylabel("Proporción")
plt.legend(title="Atrición")

# Rotando las etiquetas del eje x en 45 grados
plt.xticks(rotation=45)

# Ajustando el diseño
plt.tight_layout()

# Mostrando el gráfico
plt.show()

# %% [markdown]
# ### Heatmap de correlación

# %%
# Seleccionando solo las columnas numéricas que tengan varianza no nula
numeric_columns = df.select_dtypes(include=['number'])
numeric_columns = numeric_columns.loc[:, numeric_columns.var() != 0]

# Calculando la matriz de correlación
correlation_matrix = numeric_columns.corr()

# Creando una figura
plt.figure(figsize=(12, 9))

# Creando un mapa de calor de correlación con Seaborn
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=.5, vmin=-1, fmt = ".2f", annot_kws={"size": 8}) # 80% del tamaño original

# Añadiendo un título
plt.title("Heatmap de Correlación")

# Mostrando el gráfico
plt.show()

# %% [markdown]
# ## Visualizaciones Avanzadas
#
# ### Gráfico de Radar

# %%
import numpy as np

# Selección de dos empleados para comparar (puedes cambiar estos índices según tus necesidades)
employee1 = df.loc[10]
employee2 = df.loc[20]

# Métricas para comparar
metrics = ['JobSatisfaction', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'MonthlyIncome']
labels = ['Satisfacción Laboral', 'Equilibrio Vida-Trabajo', 'Años en la Empresa', 'Años en el Rol Actual', 'Ingreso Mensual']

# Normalización de los valores para que estén en la misma escala
values1 = [employee1[metric] / df[metric].max() for metric in metrics]
values2 = [employee2[metric] / df[metric].max() for metric in metrics]

# Agregando el primer valor al final para cerrar el círculo
values1 += values1[:1]
values2 += values2[:1]

# Número de variables
num_vars = len(labels)

# Ángulos para cada eje
angles = [n / float(num_vars) * 2 * np.pi for n in range(num_vars)]
angles += angles[:1]

# Aplicando un tema de Seaborn
sns.set_theme(style="whitegrid")

# Definiendo una paleta de colores de Seaborn
palette = sns.color_palette("husl", 2)

# Creando el gráfico de radar
plt.figure(figsize=(8, 8))
ax = plt.subplot(111, polar=True)

# Añadiendo los ejes para cada métrica
plt.xticks(angles[:-1], labels, color='grey', size=10)

# Plotting los valores para cada empleado con los colores de la paleta
ax.plot(angles, values1, linewidth=1, linestyle='solid', label='Empleado 1', color=palette[0])
ax.fill(angles, values1, alpha=0.4, color=palette[0])
ax.plot(angles, values2, linewidth=1, linestyle='solid', label='Empleado 2', color=palette[1])
ax.fill(angles, values2, alpha=0.4, color=palette[1])

# Añadiendo una leyenda
plt.legend(loc='upper right', bbox_to_anchor=(0.1, 0.1))

# Añadiendo un título
plt.title("Comparación de Empleados en Varios Aspectos")

# Mostrando el gráfico
plt.show()

# %% [markdown]
# ### Gráfico de Facetas (FacetGrid)

# %%
from itertools import product

# Creando un FacetGrid para comparar la satisfacción laboral en diferentes departamentos y niveles de educación
g = sns.FacetGrid(df, col="Department", row="EducationField", height=4, aspect=1)
# g = g.map(sns.violinplot, "JobSatisfaction", inner="quartile", palette="pastel", order=None) # Para evitar la advertencia
g = g.map(sns.histplot, "JobSatisfaction")

# Ajustando los títulos de los subplots para mostrar solo los valores de "EducationField" y "Department" en el orden correcto
for ax, (row_val, col_val) in zip(g.axes.flat, product(g.row_names, g.col_names)):
    ax.set_title(f"{col_val}, {row_val}", fontsize=10)

# Añadiendo un título global
g.fig.suptitle("Distribución de la Satisfacción Laboral por Departamento y Nivel de Educación", y=1.03, fontsize=12)

# Ajustando el diseño
plt.tight_layout()

# Mostrando el gráfico
plt.show()
# Out:
# c:\Users\mcondedesimon\OneDrive - Deloitte (O365D)\Documents\PLAYGROUND\explo_py\.venv\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\mcondedesimon\AppData\Local\Temp\ipykernel_96580\780900328.py:16: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
